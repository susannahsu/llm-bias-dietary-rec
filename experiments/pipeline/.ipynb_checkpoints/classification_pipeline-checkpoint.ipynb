# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

import re, pickle
import functools
import itertools
import string

from string import digits

# %%
with open('logit_us.pkl', 'rb') as file:
    clf = pickle.load(file)

# %%
with open('../dataset/eng_result.pkl', 'rb') as f:
    eng_result = pickle.load(f)

with open('../dataset/chn_result.pkl', 'rb') as f:
    chn_result = pickle.load(f)

with open('../dataset/port_result.pkl', 'rb') as f:
    port_result = pickle.load(f)

with open('../dataset/spanish_result.pkl', 'rb') as f:
    spanish_result = pickle.load(f)

with open('../dataset/french_result.pkl', 'rb') as f:
    french_result = pickle.load(f)

with open('../dataset/german_result.pkl', 'rb') as f:
    german_result = pickle.load(f)

with open('../dataset/greek_result.pkl', 'rb') as f:
    greek_result = pickle.load(f)

with open('../dataset/hung_result.pkl', 'rb') as f:
    hung_result = pickle.load(f)

with open('../dataset/hindi_result.pkl', 'rb') as f:
    hindi_result = pickle.load(f)

with open('../dataset/irish_result.pkl', 'rb') as f:
    irish_result = pickle.load(f)

with open('../dataset/italian_result.pkl', 'rb') as f:
    italian_result = pickle.load(f)

with open('../dataset/jap_result.pkl', 'rb') as f:
    jap_result = pickle.load(f)

with open('../dataset/arab_result.pkl', 'rb') as f:
    arab_result = pickle.load(f)

with open('../dataset/thai_result.pkl', 'rb') as f:
    thai_result = pickle.load(f)

with open('../dataset/fili_result.pkl', 'rb') as f:
    fili_result = pickle.load(f)

with open('../dataset/viet_result.pkl', 'rb') as f:
    viet_result = pickle.load(f)

with open('../dataset/kor_result.pkl', 'rb') as f:
    kor_result = pickle.load(f)

with open('../dataset/russian_result.pkl', 'rb') as f:
    russian_result = pickle.load(f)

# %% [markdown]
# ### Preprocess Data

# %%
def clean_string(s, aslist=False):
    '''Helper function to clean ingredients'''
    remove_digits = str.maketrans('', '', digits)
    remove_punctuation = str.maketrans('', '', string.punctuation)
    remove_whitespace = str.maketrans('', '', string.whitespace)

    german_ingr = {'zitrone':'lemon', 'zitronen saft':'lemon juice','zwiebel':'onions', 'öl':'oil'}

    # Remove all digits and parenthesis content from ingredients
    tmp = s.translate(remove_punctuation).lower().translate(remove_digits)
    tmp = re.sub(r'\(*\)','',tmp)

    # Remove some stop words
    alist =['low fat', 'reduced fat', 'fat free', 'fatfree', 'nonfat','gluten free', 'free range',
         'reduced sodium', 'salt free','sodium free', 'low sodium', 'sweetened','unsweetened','large','extra large','oz','®','™','oldelpaso','alfredo','knorr'
        ,'hellmannâ','orbestfoodcanolacholesterolfree','€']
    for stra in alist:
        tmp = tmp.replace(stra,'')


    # Normalize ingredient names
    alist = ['chile', 'chili','chilies','chilli','sriracha']

    for pepper in alist:
         if pepper in tmp:
            tmp = 'chili'
            break

    blist = [['flour','flour'],['tumeric','turmeric'],['yoghurt','yogurt'],['yogurt','yogurt'],['sausage','sausage'],['fillet','raw fish'],['mozzarella','mozzarella cheese'],
          ['spinach','spinach']]
    for tup in blist:
        if tup[0] in tmp:
            tmp = tup[1]

    # Translate some ingredient names to english
    if(tmp in german_ingr):
        tmp = german_ingr[tmp]

    # Remove spaces between words that defines an ingredients (e.g. “chicken breast” becomes “chickenbreast”)
    # this step is useful for the tfidf vectorization
    if not aslist:
        tmp = tmp.translate(remove_whitespace)

    return tmp

# %%
def generate_text_ingredients(df):
    df.ingredients = df.ingredients.apply(lambda x: list(map(lambda y: clean_string(y, aslist=True), x)))
    df['text_ingredients'] = df['ingredients'].apply(lambda l_ingredients : functools.reduce(lambda acc,x : acc +' ' +x,map(lambda ingred: clean_string(ingred),l_ingredients)))
    return df

# %%
eng_df = generate_text_ingredients(eng_result)

# %%
chn_df = generate_text_ingredients(chn_result)

# %%
port_df = generate_text_ingredients(port_result)

# %%
spanish_df = generate_text_ingredients(spanish_result)

# %%
french_df = generate_text_ingredients(french_result)

# %%
german_df = generate_text_ingredients(german_result)

# %%
greek_df = generate_text_ingredients(greek_result)

# %%
hung_df = generate_text_ingredients(hung_result)

# %%
hindi_df = generate_text_ingredients(hindi_result)

# %%
irish_df = generate_text_ingredients(irish_result)

# %%
italian_df = generate_text_ingredients(italian_result)

# %%
jap_df = generate_text_ingredients(jap_result)

# %%
arab_df = generate_text_ingredients(arab_result)

# %%
thai_df = generate_text_ingredients(thai_result)

# %%
fili_df = generate_text_ingredients(fili_result)

# %%
viet_df = generate_text_ingredients(viet_result)

# %%
kor_df = generate_text_ingredients(kor_result)

# %%
russian_df = generate_text_ingredients(russian_result)

# %%
with open('tfidf_vectorizer_us.pkl', 'rb') as file:
    vectorizer = pickle.load(file)

# %%
eng_df
# Out:
#                          name  \
# 0                quinoa salad
# 1               avocado toast
# 2               smoothie bowl
# 3              chickpea curry
# 4        stuffed bell peppers
# ..                        ...
# 295              baked salmon
# 296     chicken avocado salad
# 297             smoothie bowl
# 298  gluten-free oat pancakes
# 299                kale chips
#
#                                            ingredients  \
# 0    [quinoa, cucumber, cherry tomatoes, red onion,...
# 1    [whole grain bread, ripe avocado, lemon juice,...
# 2    [fren berries, banana, spinach, almond milk, g...
# 3    [chickpeas, coconut milk, onion, tomato, garli...
# 4    [bell peppers, quinoa, black beans, corn, toma...
# ..                                                 ...
# 295   [raw fish, lemon, dill, olive oil, salt, pepper]
# 296  [chicken breast, avocado, corn, cilantro, lime...
# 297  [fren berries, banana, spinach, almond milk, g...
# 298  [glutenfree oats, banana, eggs, baking powder,...
# 299                            [kale, olive oil, salt]
#
#                                       text_ingredients
# 0    quinoa cucumber cherrytomatoes redonion fetach...
# 1    wholegrainbread ripeavocado lemonjuice salt pe...
# 2    frenberries banana spinach almondmilk granola ...
# 3    chickpeas coconutmilk onion tomato garlic curr...
# 4    bellpeppers quinoa blackbeans corn tomato ched...
# ..                                                 ...
# 295            rawfish lemon dill oliveoil salt pepper
# 296  chickenbreast avocado corn cilantro limejuice ...
# 297  frenberries banana spinach almondmilk granola ...
# 298  glutenfreeoats banana eggs bakingpowder vanill...
# 299                                 kale oliveoil salt
#
# [300 rows x 3 columns]

# %% [markdown]
# ### English Version Classification

# %%
eng_X = vectorizer.transform(eng_df['text_ingredients'])
eng_pred = clf.predict(eng_X)
eng_df['cuisine'] = eng_pred
eng_df
# Out:
#                          name  \
# 0                quinoa salad
# 1               avocado toast
# 2               smoothie bowl
# 3              chickpea curry
# 4        stuffed bell peppers
# ..                        ...
# 295              baked salmon
# 296     chicken avocado salad
# 297             smoothie bowl
# 298  gluten-free oat pancakes
# 299                kale chips
#
#                                            ingredients  \
# 0    [quinoa, cucumber, cherry tomatoes, red onion,...
# 1    [whole grain bread, ripe avocado, lemon juice,...
# 2    [fren berries, banana, spinach, almond milk, g...
# 3    [chickpeas, coconut milk, onion, tomato, garli...
# 4    [bell peppers, quinoa, black beans, corn, toma...
# ..                                                 ...
# 295   [raw fish, lemon, dill, olive oil, salt, pepper]
# 296  [chicken breast, avocado, corn, cilantro, lime...
# 297  [fren berries, banana, spinach, almond milk, g...
# 298  [glutenfree oats, banana, eggs, baking powder,...
# 299                            [kale, olive oil, salt]
#
#                                       text_ingredients      cuisine
# 0    quinoa cucumber cherrytomatoes redonion fetach...        greek
# 1    wholegrainbread ripeavocado lemonjuice salt pe...  southern_us
# 2    frenberries banana spinach almondmilk granola ...    brazilian
# 3    chickpeas coconutmilk onion tomato garlic curr...       indian
# 4    bellpeppers quinoa blackbeans corn tomato ched...      mexican
# ..                                                 ...          ...
# 295            rawfish lemon dill oliveoil salt pepper      russian
# 296  chickenbreast avocado corn cilantro limejuice ...      mexican
# 297  frenberries banana spinach almondmilk granola ...    brazilian
# 298  glutenfreeoats banana eggs bakingpowder vanill...      italian
# 299                                 kale oliveoil salt      italian
#
# [300 rows x 4 columns]

# %% [markdown]
# ### Chinese Version Classification

# %%
chn_X = vectorizer.transform(chn_df['text_ingredients'])
chn_pred = clf.predict(chn_X)
chn_df['cuisine'] = chn_pred
chn_df
# Out:
#                                   name  \
# 0                          green salad
# 1                               hummus
# 2                       grilled salmon
# 3                       vegetable soup
# 4                    oatmeal breakfast
# ..                                 ...
# 295         grilled mackerel with lime
# 296                vegetable bean stew
# 297  roasted pumpkin salad with apples
# 298                    sugar-free cake
# 299                            quichou
#
#                                            ingredients  \
# 0    [spinach, kale, cucumber, cherry tomatoes, avo...
# 1    [chickpeas, garlic, tahini, olive oil, lemon j...
# 2    [salmon, olive oil, lemon, rosemary, salt, bla...
# 3    [carrot, onion, garlic, celery, broccoli, toma...
# 4                  [oatmeal, milk, fruit, honey, nuts]
# ..                                                 ...
# 295  [mackerel, lime, ginger slices, garlic, sour b...
# 296  [bean, potato, carrot, cabbage, tomato, zucchi...
# 297  [pumpkin, apple, walnut, cranberry, jackfruit,...
# 298  [almond powder, coconut powder, vanilla extrac...
# 299  [oatmeal, honey, almonds, walnuts, yucca necta...
#
#                                       text_ingredients      cuisine
# 0    spinach kale cucumber cherrytomatoes avocado l...        greek
# 1    chickpeas garlic tahini oliveoil lemonjuice sa...        greek
# 2        salmon oliveoil lemon rosemary salt blackbean      italian
# 3    carrot onion garlic celery broccoli tomato wat...     filipino
# 4                        oatmeal milk fruit honey nuts  southern_us
# ..                                                 ...          ...
# 295  mackerel lime gingerslices garlic sourbeans ch...    brazilian
# 296  bean potato carrot cabbage tomato zucchini bro...      italian
# 297  pumpkin apple walnut cranberry jackfruit pinea...     moroccan
# 298  almondpowder coconutpowder vanillaextract cran...      italian
# 299  oatmeal honey almonds walnuts yuccanectar fres...      italian
#
# [300 rows x 4 columns]

# %% [markdown]
# ### Portuguese Version Classification

# %%
port_X = vectorizer.transform(port_df['text_ingredients'])
port_pred = clf.predict(port_X)
port_df['cuisine'] = port_pred
port_df
# Out:
#                               name  \
# 0     quinoa salad with vegetables
# 1                   green smoothie
# 2    egg white omelet with spinach
# 3                      lentil soup
# 4            grilled chicken salad
# ..                             ...
# 295                      guacamole
# 296                     night oats
# 297                      açaí bowl
# 298                     tuna salad
# 299         quinoa vegetable salad
#
#                                            ingredients  \
# 0    [quinoa, cucumber, cherry tomato, pepper, lemo...
# 1    [spinach, banana, mango, almond milk, honey, c...
# 2    [egg whites, spinach, tomato, feta cheese, sal...
# 3    [lentils, carrots, onions, garlic, thyme, vege...
# 4    [chicken breast, romaine lettuce, croutons, pa...
# ..                                                 ...
# 295  [avocado, tomato, onion, cilantro, jalapeño, l...
# 296  [oats, almond milk, yogurt, honey, banana, cin...
# 297  [açaí pulp, banana, strawberry, granola, honey...
# 298  [tuna in water, light mayonnaise, celery, carr...
# 299  [quinoa, cucumber, cherry tomato, red pepper, ...
#
#                                       text_ingredients    cuisine
# 0    quinoa cucumber cherrytomato pepper lemon oliv...      greek
# 1           spinach banana mango almondmilk honey chia  brazilian
# 2      eggwhites spinach tomato fetacheese salt pepper      greek
# 3    lentils carrots onions garlic thyme vegetableb...   jamaican
# 4    chickenbreast romainelettuce croutons parmesan...    italian
# ..                                                 ...        ...
# 295  avocado tomato onion cilantro jalapeño lemon salt    mexican
# 296       oats almondmilk yogurt honey banana cinnamon      greek
# 297  açaípulp banana strawberry granola honey cocon...  brazilian
# 298  tunainwater lightmayonnaise celery carrot redo...   american
# 299  quinoa cucumber cherrytomato redpepper redonio...    spanish
#
# [300 rows x 4 columns]

# %% [markdown]
# ### Spanish Version Classification

# %%
spanish_X = vectorizer.transform(spanish_df['text_ingredients'])
spanish_pred = clf.predict(spanish_X)
spanish_df['cuisine'] = spanish_pred
spanish_df
# Out:
#                              name  \
# 0             mediterranean salad
# 1        kale and banana smoothie
# 2          quinoa with vegetables
# 3                     lentil soup
# 4                   tofu stir fry
# ..                            ...
# 295     vegetable and hummus wrap
# 296        oatmeal and fruit bowl
# 297    chickpea and spinach salad
# 298  salmon baked with vegetables
# 299                  carrot cream
#
#                                            ingredients  \
# 0    [cherry tomatoes, cucumber, red onion, feta ch...
# 1    [kale, banana, yogurt, honey, almonds, almond ...
# 2    [quinoa, zucchini, red pepper, onion, garlic, ...
# 3    [lentils, tomato, carrot, celery, onion, garli...
# 4    [tofu, broccoli, carrot, pepper, soy sauce, ga...
# ..                                                 ...
# 295  [whole wheat tortilla, hummus, romaine lettuce...
# 296  [oatmeal, almond milk, banana, blueberries, al...
# 297  [chickpeas, spinach, red pepper, onion purple,...
# 298      [salmon, asparagus, lemon, pepper, olive oil]
# 299  [carrot, onion, garlic, vegetable broth, cocon...
#
#                                       text_ingredients   cuisine
# 0    cherrytomatoes cucumber redonion fetacheese ka...     greek
# 1          kale banana yogurt honey almonds almondmilk    indian
# 2    quinoa zucchini redpepper onion garlic vegetab...   italian
# 3    lentils tomato carrot celery onion garlic cumi...   mexican
# 4    tofu broccoli carrot pepper soysauce garlic gi...   chinese
# ..                                                 ...       ...
# 295  wholewheattortilla hummus romainelettuce tomat...     greek
# 296  oatmeal almondmilk banana blueberries almonds ...    french
# 297  chickpeas spinach redpepper onionpurple lemon ...  moroccan
# 298             salmon asparagus lemon pepper oliveoil   italian
# 299  carrot onion garlic vegetablebroth coconutcrea...    indian
#
# [300 rows x 4 columns]
